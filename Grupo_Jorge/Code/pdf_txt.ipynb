# %% [markdown]
# # Conversion de pdf a texto
#
# **Estudiantes:** Elian Amado, Sebastian Guzman, Jorge Parrado, Duvan Salcedo y David Urrego

# %%
pip install aspose-words
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# pdf = '/content/drive/MyDrive/PDF-IA/Data relacionada/02_FCT_BIGDATA_200730.pdf'
# pdf = '/content/drive/MyDrive/PDF-IA/Data relacionada/ANEXO_TECNICO_-_MODULO_IA_-_CHATBOTS.pdf'
# docx = '/content/drive/MyDrive/PDF-IA/Data relacionada/pliego concurso de méritos CMA 003 DE 2020.docx'
docx = '/content/drive/MyDrive/PDF-IA/Data relacionada/Anexo 1. Especificaciones Técnicas Proceso -Contrato Interadministrativo V1.3 29092020.docx'

# %%
import aspose.words as aw

doc = aw.Document(docx)

# print(pdf[-3:].replace('pdf', 'txt'))

doc.save('/content/drive/MyDrive/PDF-IA/Data relacionada/pliego concurso de méritos CMA 003 DE 2020.txt')

# %%
# !pip install PyMuPDF
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.8 MB 5.1 MB/s
# ...

# %%
import fitz
# documento = fitz.open(docx)

print('Número de páginas: ', documento.page_count)
print('Metadatos: ', documento.metadata)

pagina = documento.load_page(0)
text = pagina.get_text('text')
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileDataError                             Traceback (most recent call last)
# <ipython-input-36-ec57f4344b5e> in <module>
#       1 import fitz
# ----> 2 documento = fitz.open(pdf)
#       3 print('Número de páginas: ', documento.page_count)
#       4 print('Metadatos: ', documento.metadata)
#       5
#
# /usr/local/lib/python3.7/dist-packages/fitz/fitz.py in __init__(self, filename, stream, filetype, rect, width, height, fontsize)
#    3874
#    3875
# -> 3876         _fitz.Document_swiginit(self, _fitz.new_Document(filename, stream, filetype, rect, width, height, fontsize))
#    3877
#    3878         if self.thisown:
#
# FileDataError: cannot open broken document

# %%
doc = fitz.open(pdf)
# output = open(pdf + '.txt', 'wb')
output = open(pdf + '.docx', 'wb')

for pages in doc:
    text = pages.get_text().encode('utf8')
    output.write(text)
    output.write(b'\n-----\n')

output.close()
# Out:
# ---------------------------------------------------------------------------
# FileDataError                             Traceback (most recent call last)
# <ipython-input-37-1009d5759879> in <module>
# ----> 1 doc = fitz.open(pdf)
#       2 # output = open(pdf + '.txt', 'wb')
#       3 output = open(pdf + '.docx', 'wb')
#       4
#       5 for pages in doc:
#
# /usr/local/lib/python3.7/dist-packages/fitz/fitz.py in __init__(self, filename, stream, filetype, rect, width, height, fontsize)
#    3874
#    3875
# -> 3876         _fitz.Document_swiginit(self, _fitz.new_Document(filename, stream, filetype, rect, width, height, fontsize))
#    3877
#    3878         if self.thisown:
#
# FileDataError: cannot open broken document

# %%
pip install docx2txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=b1a11eefa1abc31bd66bd6b4ac0b85320732d6f1d9c48d94cae095aab625c7bb
#   Stored in directory: /root/.cache/pip/wheels/b7/20/b2/473e3aea9a0c0d3e7b2f7bd81d06d0794fec12752733d1f3a8
# Successfully built docx2txt
# ...

# %%
import docx2txt

text = docx2txt.process(docx)

with open(docx + '.txt', 'w') as text_file:
    print(text, file=text_file)
